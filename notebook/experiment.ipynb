# %%
import os 
os.getcwd()
# Out:
# 'd:\\Ineuron\\Project\\Adult_Census_Income_Prediction\\notebook'

# %%
os.chdir("d:\\Ineuron\Project\\Adult_Census_Income_Prediction")

# %%
os.getcwd()
# Out:
# 'd:\\Ineuron\\Project\\Adult_Census_Income_Prediction'

# %%
schema_file_path = os.path.join("config","schema.yaml")

# %%
schema_file_path
# Out:
# 'config\\schema.yaml'

# %%
import yaml

# %%
config_schema_info  = None

with open(schema_file_path,"rb") as schema_yaml_file:
    config_schema_info = yaml.safe_load(schema_yaml_file)

# %%
config_schema_info
# Out:
# {'columns': {'age': 'int64',
#   'workclass': 'object',
#   'fnlwgt': 'int64',
#   'education': 'object',
#   'education-num': 'int64',
#   'marital-status': 'object',
#   'occupation': 'object',
#   'relationship': 'object',
#   'race': 'object',
#   'sex': 'object',
#   'capital-gain': 'int64',
#   'capital-loss': 'int64',
#   'hours-per-week': 'int64',
#   'country': 'object',
#   'salary': 'object'},
#  'numerical_columns': ['age',
#   'fnlwgt',
#   'education-num',
#   'capital-gain',
#   'capital-loss',
#   'hours-per-week'],
#  'categorical_columns': ['workclass',
#   'education',
#   'marital-status',
#   'occupation',
#   'relationship',
#   'race',
#   'sex',
#   'country'],
#  'target_column': 'salary',
#  'threshold': 0.7}

# %%
config_file_path = os.path.join("config","config.yaml")

# %%
config_file_path
# Out:
# 'config\\config.yaml'

# %%
import yaml

# %%
config_info  = None

with open(config_file_path,"rb") as yaml_file:
    config_info = yaml.safe_load(yaml_file)

# %%
import pandas as pd

# %%
config_info
# Out:
# {'training_pipeline_config': {'pipeline_name': 'incomeprediction',
#   'artifact_dir': 'artifact'},
#  'data_ingestion_config': {'dataset_download_url': 'D:\\Ineuron\\Project\\Datasets\\adultincomeprediction.csv',
#   'raw_data_dir': 'raw_data',
#   'ingested_dir': 'ingested_data',
#   'ingested_train_dir': 'train',
#   'ingested_test_dir': 'test'},
#  'data_validation_config': {'schema_dir': 'config',
#   'schema_file_name': 'schema.yaml',
#   'report_file_name': 'report.json',
#   'report_page_file_name': 'report.html'},
#  'data_transformation_config': {'transformed_dir': 'transformed_data',
#   'transformed_train_dir': 'train',
#   'transformed_test_dir': 'test',
#   'preprocessing_dir': 'preprocessed',
#   'preprocessed_object_file_name': 'preprocessed.pkl'},
#  'model_trainer_config': {'trained_model_dir': 'trained_model',
#   'model_file_name': 'model.pkl',
#   'base_accuracy': 0.6,
#   'model_config_dir': 'config',
#   'model_config_file_name': 'model.yaml'},
#  'model_evaluation_config': {'model_evaluation_file_name': 'model_evaluation.yaml'},
#  'model_pusher_config': {'model_export_dir': 'saved_models'}}

# %%
config_info["training_pipeline_config"]
# Out:
# {'pipeline_name': 'incomeprediction', 'artifact_dir': 'artifact'}

# %%
from incomeprediction.constant import *

# %%
TRAINING_PIPELINE_CONFIG_KEY
# Out:
# 'training_pipeline_config'

# %%
config_info[TRAINING_PIPELINE_CONFIG_KEY]
# Out:
# {'pipeline_name': 'incomeprediction', 'artifact_dir': 'artifact'}

# %%
config_info[TRAINING_PIPELINE_CONFIG_KEY][TRAINING_PIPELINE_NAME_KEY]
# Out:
# 'incomeprediction'

# %%
ROOT_DIR
# Out:
# 'd:\\Ineuron\\Project\\Adult_Census_Income_Prediction'

# %%
training_pipeline_config = config_info[TRAINING_PIPELINE_CONFIG_KEY]
artifact_dir = os.path.join(ROOT_DIR,
training_pipeline_config[TRAINING_PIPELINE_NAME_KEY],
training_pipeline_config[TRAINING_PIPELINE_ARTIFACT_DIR_KEY]
)

# %%
artifact_dir
# Out:
# 'd:\\Ineuron\\Project\\Adult_Census_Income_Prediction\\incomeprediction\\artifact'

# %%
from incomeprediction.constant import DATA_INGESTION_CONFIG_KEY

# %%
 DATA_INGESTION_CONFIG_KEY
# Out:
# 'data_ingestion_config'

# %%
from incomeprediction.logger import logging
from incomeprediction.constant import *
from incomeprediction.util.util import read_yaml_file
from incomeprediction.entity.config_entity import *
from incomeprediction.exception import incomepredictionexception
import os,sys
import pandas as pd

#download_url = D:\Ineuron\Project\Datasets\adultincomeprediction.csv

# %%
 dataset_download_url = config_info[DATA_INGESTION_CONFIG_KEY][DATA_INGESTION_DOWNLOAD_URL_KEY]

# %%
dataset_download_url
# Out:
# 'D:\\Ineuron\\Project\\Datasets\\adultincomeprediction.csv'

# %%
raw_data_dir = config_info[DATA_INGESTION_CONFIG_KEY][DATA_INGESTION_RAW_DATA_DIR_KEY]

# %%
raw_data_dir1 = os.path.join(ROOT_DIR,raw_data_dir)

# %%
raw_data_dir1
# Out:
# 'd:\\Ineuron\\Project\\Adult_Census_Income_Prediction\\raw_data'

# %%
import pandas as pd
train_df = pd.read_csv(F"D:\\Ineuron\\Project\\Adult_Census_Income_Prediction\\incomeprediction\\artifact\data_ingestion\\22-08-08--11-50-12\\ingested_data\\train\\adultincomeprediction.csv", na_values= " ?")

# %%
train_df.shape
# Out:
# (22792, 15)

# %%
train_df.isnull().sum()
# Out:
# age                  0
# workclass         1267
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1274
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# country            405
# salary               0
# dtype: int64

# %%
# import numpy as np
# from sklearn.impute import SimpleImputer
# imp_mode = SimpleImputer(strategy='most_frequent')
# imp_mode.fit(train_df)

# %%
null_columns = train_df.loc[:, train_df.isnull().any()].columns.to_list()
null_columns
# Out:
# ['workclass', 'occupation', 'country']

# %%
#cols = ["workclass", "native-country"]
train_df[null_columns]=train_df[null_columns].fillna(train_df.mode().iloc[0])

# %%
train_df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# country           0
# salary            0
# dtype: int64

# %%
train_df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  22792.000000  2.279200e+04   22792.000000  22792.000000  22792.000000
# mean      38.568050  1.896914e+05      10.091216   1045.572613     89.470648
# std       13.645603  1.056332e+05       2.578429   7144.535491    406.839418
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.177890e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.782330e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.373080e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    22792.000000
# mean        40.384565
# std         12.288751
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22792 entries, 0 to 22791
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             22792 non-null  int64
#  1   workclass       22792 non-null  object
#  2   fnlwgt          22792 non-null  int64
#  3   education       22792 non-null  object
#  4   education-num   22792 non-null  int64
#  5   marital-status  22792 non-null  object
#  6   occupation      22792 non-null  object
#  7   relationship    22792 non-null  object
#  8   race            22792 non-null  object
#  9   sex             22792 non-null  object
#  10  capital-gain    22792 non-null  int64
#  11  capital-loss    22792 non-null  int64
#  12  hours-per-week  22792 non-null  int64
#  13  country         22792 non-null  object
#  14  salary          22792 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 2.6+ MB

# %%
for col in train_df.columns:
    if train_df[col].dtype == 'object':
        print(col)
    else:
        pass
# Out:
# workclass
# education
# marital-status
# occupation
# relationship
# race
# sex
# country
# salary

# %%
from sklearn.preprocessing import LabelEncoder
for col in train_df.columns:
    if train_df[col].dtype == 'object':
        le = LabelEncoder()
        train_df[col] = le.fit_transform(train_df[col].astype(str))

# %%
train_df.head()
# Out:
#    age  workclass  fnlwgt  education  education-num  marital-status  \
# 0   34          5   56460         11              9               2
# 1   48          5  243631         15             10               2
# 2   23          6   56402         15             10               2
# 3   56          1  255406         11              9               0
# 4   17          3  297246          1              7               4
#
#    occupation  relationship  race  sex  capital-gain  capital-loss  \
# 0           4             5     4    0             0          2179
# 1           2             0     0    1          7688             0
# 2           9             0     4    1             0             0
# 3           3             1     4    0             0             0
# 4           8             3     4    0             0             0
#
#    hours-per-week  country  salary
# 0              12       38       0
# 1              40       38       1
# 2              30       38       0
# 3              40       38       0
# 4               9       38       0

# %%
train_df.describe().T
# Out:
#                   count           mean            std      min       25%  \
# age             22792.0      38.568050      13.645603     17.0      28.0
# workclass       22792.0       3.100123       1.108234      0.0       3.0
# fnlwgt          22792.0  189691.382810  105633.215138  12285.0  117789.0
# education       22792.0      10.296815       3.868415      0.0       9.0
# education-num   22792.0      10.091216       2.578429      1.0       9.0
# marital-status  22792.0       2.610653       1.502063      0.0       2.0
# occupation      22792.0       6.116313       3.968607      0.0       3.0
# relationship    22792.0       1.442348       1.605438      0.0       0.0
# race            22792.0       3.661548       0.851101      0.0       4.0
# sex             22792.0       0.669489       0.470407      0.0       0.0
# capital-gain    22792.0    1045.572613    7144.535491      0.0       0.0
# capital-loss    22792.0      89.470648     406.839418      0.0       0.0
# hours-per-week  22792.0      40.384565      12.288751      1.0      40.0
# country         22792.0      36.385618       6.101736      0.0      38.0
# salary          22792.0       0.242497       0.428603      0.0       0.0
#
#                      50%       75%        max
# age                 37.0      48.0       90.0
# workclass            3.0       3.0        7.0
# fnlwgt          178233.0  237308.0  1484705.0
# education           11.0      12.0       15.0
# education-num       10.0      12.0       16.0
# marital-status       2.0       4.0        6.0
# occupation           6.0       9.0       13.0
# relationship         1.0       3.0        5.0
# race                 4.0       4.0        4.0
# sex                  1.0       1.0        1.0
# capital-gain         0.0       0.0    99999.0
# capital-loss         0.0       0.0     4356.0
# hours-per-week      40.0      45.0       99.0
# country             38.0      38.0       40.0
# salary               0.0       0.0        1.0

# %%
train_df.head()
# Out:
#    age  workclass  fnlwgt  education  education-num  marital-status  \
# 0   34          5   56460         11              9               2
# 1   48          5  243631         15             10               2
# 2   23          6   56402         15             10               2
# 3   56          1  255406         11              9               0
# 4   17          3  297246          1              7               4
#
#    occupation  relationship  race  sex  capital-gain  capital-loss  \
# 
# education-num       0.125547      0.088899        0.147670  0.092435  0.336876
# marital-status      0.047141      0.035851        0.186486  0.025081  0.201674
# occupation          0.017743      0.013037        0.010215  0.003753  0.035008
# relationship        0.055617      0.060437        0.249800  0.013262  0.246956
# race                0.005698      0.022881        0.044265  0.115976  0.072725
# sex                 0.044635      0.044469        0.231592  0.005669  0.214955
# capital-gain        1.000000      0.032185        0.084682  0.004543  0.222450
# capital-loss        0.032185      1.000000        0.049888  0.014540  0.148782
# hours-per-week      0.084682      0.049888        1.000000  0.006667  0.233351
# country             0.004543      0.014540        0.006667  1.000000  0.028148
# salary              0.222450      0.148782        0.233351  0.028148  1.000000

# %%
s = corr_matrix.unstack()
so = s.sort_values(kind="quicksort")
negative_pairs = so[so < 0.5]

print(negative_pairs)
# Out:
# country        age               0.000241
# age            country           0.000241
# salary         workclass         0.001351
# workclass      salary            0.001351
#                country           0.001505
#                                    ...
# age            marital-status    0.269857
# education-num  salary            0.336876
# salary         education-num     0.336876
# education-num  education         0.358324
# education      education-num     0.358324
# Length: 208, dtype: float64

# %%
strong_pairs = so[abs(so) > 0.5]
strong_pairs
# Out:
# sex             relationship      0.581327
# relationship    sex               0.581327
# age             age               1.000000
# relationship    relationship      1.000000
# hours-per-week  hours-per-week    1.000000
# capital-loss    capital-loss      1.000000
# capital-gain    capital-gain      1.000000
# sex             sex               1.000000
# race            race              1.000000
# occupation      occupation        1.000000
# marital-status  marital-status    1.000000
# education-num   education-num     1.000000
# education       education         1.000000
# fnlwgt          fnlwgt            1.000000
# workclass       workclass         1.000000
# country         country           1.000000
# salary          salary            1.000000
# dtype: float64

# %%
#threshold = 0.7
def correlation(dataset, thres):
    col_corr = set() # Set of all the names of deleted columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if (corr_matrix.iloc[i, j] >= thres) and (corr_matrix.columns[j] not in col_corr):
                colname = corr_matrix.columns[i] # getting the name of column
                col_corr.add(colname)
    print(col_corr)

# %%
correlation(dataset = train_df,thres = 0.5)
# Out:
# set()

# %%
df.head()
# Out:
#         age  workclass    fnlwgt  education  education-num  marital-status  \
# 0 -0.334771   1.714366 -1.261292   0.181780      -0.423219       -0.406552
# 1  0.691223   1.714366  0.510642   1.215818      -0.035377       -0.406552
# 2 -1.140909   2.616722 -1.261841   1.215818      -0.035377       -0.406552
# 3  1.277505  -1.895059  0.622115   0.181780      -0.423219       -1.738082
# 4 -1.580621  -0.090346  1.018212  -2.403314      -1.198902        0.924979
#
#    occupation  relationship      race       sex  capital-gain  capital-loss  \
# 0   -0.533275      2.216049  0.397673 -1.423243     -0.146349      5.136118
# 1   -1.037241     -0.898434 -4.302226  0.702621      0.929742     -0.219921
# 2    0.726640     -0.898434  0.397673  0.702621     -0.146349     -0.219921
# 3   -0.785258     -0.275537  0.397673 -1.423243     -0.146349     -0.219921
# 4    0.474657      0.970256  0.397673 -1.423243     -0.146349     -0.219921
#
#    hours-per-week   country    salary
# 0       -2.309851  0.264583 -0.565798
# 1       -0.031295  0.264583  1.767415
# 2       -0.845065  0.264583 -0.565798
# 3       -0.031295  0.264583 -0.565798
# 4       -2.553982  0.264583 -0.565798

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectPercentile, chi2
from sklearn.preprocessing import StandardScaler


# Create a feature-selection transform, a scaler and an instance of SVM that we
# combine together to have a full-blown estimator

data_transfromation = Pipeline(
    [ 
        ("chi-square", SelectPercentile(chi2)),
        ("scaler", StandardScaler())
    ]
)

# %%
x = train_df.iloc[:,:-1]
y = train_df.iloc[:,-1]

# %%
data_transfromation.fit(x,y)
# Out:
# Pipeline(steps=[('chi-square',
#                  SelectPercentile(score_func=<function chi2 at 0x000001907F2BE708>)),
#                 ('scaler', StandardScaler())])

# %%
train_df.describe()
# Out:
#                 age     workclass        fnlwgt     education  education-num  \
# count  22792.000000  22792.000000  2.279200e+04  22792.000000   22792.000000
# mean      38.568050      3.100123  1.896914e+05     10.296815      10.091216
# std       13.645603      1.108234  1.056332e+05      3.868415       2.578429
# min       17.000000      0.000000  1.228500e+04      0.000000       1.000000
# 25%       28.000000      3.000000  1.177890e+05      9.000000       9.000000
# 50%       37.000000      3.000000  1.782330e+05     11.000000      10.000000
# 75%       48.000000      3.000000  2.373080e+05     12.000000      12.000000
# max       90.000000      7.000000  1.484705e+06     15.000000      16.000000
#
#        marital-status    occupation  relationship          race           sex  \
# count    22792.000000  22792.000000  22792.000000  22792.000000  22792.000000
# mean         2.610653      6.116313      1.442348      3.661548      0.669489
# std          1.502063      3.968607      1.605438      0.851101      0.470407
# min          0.000000      0.000000      0.000000      0.000000      0.000000
# 25%          2.000000      3.000000      0.000000      4.000000      0.000000
# 50%          2.000000      6.000000      1.000000      4.000000      1.000000
# 75%          4.000000      9.000000      3.000000      4.000000      1.000000
# max          6.000000     13.000000      5.000000      4.000000      1.000000
#
#        capital-gain  capital-loss  hours-per-week       country        salary
# count  22792.000000  22792.000000    22792.000000  22792.000000  22792.000000
# mean    1045.572613     89.470648       40.384565     36.385618      0.242497
# std     7144.535491    406.839418       12.288751      6.101736      0.428603
# min        0.000000      0.000000        1.000000      0.000000      0.000000
# 25%        0.000000      0.000000       40.000000     38.000000      0.000000
# 50%        0.000000      0.000000       40.000000     38.000000      0.000000
# 75%        0.000000      0.000000       45.000000     38.000000      0.000000
# max    99999.000000   4356.000000       99.000000     40.000000      1.000000

# %%
train_df.corr()
# Out:
#                      age  workclass    fnlwgt  education  education-num  \
# age             1.000000   0.044989 -0.076223  -0.005767       0.041348
# workclass       0.044989   1.000000 -0.024128   0.007488       0.011667
# fnlwgt         -0.076223  -0.024128  1.000000  -0.034055      -0.041946
# education      -0.005767   0.007488 -0.034055   1.000000       0.358324
# education-num   0.041348   0.011667 -0.041946   0.358324       1.000000
# marital-status -0.269857  -0.028823  0.031352  -0.036692      -0.070292
# occupation     -0.002969   0.013613  0.002231  -0.048297       0.065726
# relationship   -0.269445  -0.057200  0.012088  -0.017122      -0.099102
# race            0.026136   0.054163 -0.020626   0.015854       0.032523
# sex             0.089279   0.071812  0.024053  -0.018978       0.020950
# capital-gain    0.077956   0.024716  0.007383   0.030066       0.125547
# capital-loss    0.057027   0.002332 -0.012034   0.021414       0.088899
# hours-per-week  0.069102   0.039964 -0.016227   0.061889       0.147670
# country         0.000241   0.001505 -0.058229   0.077497       0.092435
# salary          0.235857   0.001351 -0.008032   0.076572       0.336876
#
#                 marital-status  occupation  relationship      race       sex  \
# age                  -0.269857   -0.002969     -0.269445  0.026136  0.089279
# workclass            -0.028823    0.013613     -0.057200  0.054163  0.071812
# fnlwgt                0.031352    0.002231      0.012088 -0.020626  0.024053
# education            -0.036692   -0.048297     -0.017122  0.015854 -0.018978
# education-num        -0.070292    0.065726     -0.099102  0.032523  0.020950
# marital-status        1.000000    0.032991      0.190728 -0.067525 -0.126676
# occupation            0.032991    1.000000     -0.037537 -0.007492  0.046564
# relationship          0.190728   -0.037537      1.000000 -0.113313 -0.581327
# race                 -0.067525   -0.007492     -0.113313  1.000000  0.084983
# sex                  -0.126676    0.046564     -0.581327  0.084983  1.000000
# capital-gain         -0.047141    0.017743     -0.055617  0.005698  0.044635
# capital-loss         -0.035851    0.013037     -0.060437  0.022881  0.044469
# hours-per-week       -0.186486   -0.010215     -0.249800  0.044265  0.231592
# country              -0.025081   -0.003753     -0.013262  0.115976  0.005669
# salary               -0.201674    0.035008     -0.246956  0.072725  0.214955
#
#                 capital-gain  capital-loss  hours-per-week   country    salary
# age                 0.077956      0.057027        0.069102  0.000241  0.235857
# workclass           0.024716      0.002332        0.039964  0.001505  0.001351
# fnlwgt              0.007383     -0.012034       -0.016227 -0.058229 -0.008032
# education           0.030066      0.021414        0.061889  0.077497  0.076572
# education-num       0.125547      0.088899        0.147670  0.092435  0.336876
# marital-status     -0.047141     -0.035851       -0.186486 -0.025081 -0.201674
# occupation          0.017743      0.013037       -0.010215 -0.003753  0.035008
# relationship       -0.055617     -0.060437       -0.249800 -0.013262 -0.246956
# race                0.005698      0.022881        0.044265  0.115976  0.072725
# sex                 0.044635      0.044469        0.231592  0.005669  0.214955
# capital-gain        1.000000     -0.032185        0.084682  0.004543  0.222450
# capital-loss       -0.032185      1.000000        0.049888  0.014540  0.148782
# hours-per-week      0.084682      0.049888        1.000000  0.006667  0.233351
# country             0.004543      0.014540        0.006667  1.000000  0.028148
# salary              0.222450      0.148782        0.233351  0.028148  1.000000

# %%
corr_matrix = train_df.corr()

# %%
threshold = 0.8
col_corr = set()
for i in range(len(corr_matrix.columns)):
                for j in range(i):
                    if abs(corr_matrix.iloc[i,j])> threshold:
                        colname = corr_matrix.columns[i]
                        col_corr.add(colname)

# %%
col_corr
# Out:
# set()

# %%
train_df.head()
# Out:
#    age  workclass  fnlwgt  education  education-num  marital-status  \
# 0   34          5   56460         11              9               2
# 1   48          5  243631         15             10               2
# 2   23          6   56402         15             10               2
# 3   56          1  255406         11              9               0
# 4   17          3  297246          1              7               4
#
#    occupation  relationship  race  sex  capital-gain  capital-loss  \
# 0           4             5     4    0             0          2179
# 1           2             0     0    1          7688             0
# 2           9             0     4    1             0             0
# 3           3             1     4    0             0             0
# 4           8             3     4    0             0             0
#
#    hours-per-week  country  salary
# 0              12       38       0
# 1              40       38       1
# 2              30       38       0
# 3              40       38       0
# 4               9       38       0
